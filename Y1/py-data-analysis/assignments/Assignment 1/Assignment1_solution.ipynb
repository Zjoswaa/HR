# %% [markdown]
# # Assignment 1

# %% [markdown]
# ## - To complete this assignment, you must write the appropriate code instead of #TODO to produce the output you see in the following cell.

# %% [markdown]
# ## Instructions:

# %% [markdown]
# ### Import Pandas and NumPy libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Use the provided dataset to create your dataframe

# %%
df = pd.read_excel('assignment_dataset.xlsx')

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# ### 2. Data Manipulation and Analysis

# %% [markdown]
# ##### - Explore the dataset with info method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  15 non-null     int64
#  1   Age                   15 non-null     int64
#  2   Role                  15 non-null     object
#  3   City                  15 non-null     object
#  4   Education             15 non-null     object
#  5   Experience            15 non-null     int64
#  6   Salary                15 non-null     int64
#  7   AdditionalExperience  15 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 1.1+ KB

# %% [markdown]
# ### 3. DataFrame Operations

# %% [markdown]
# ##### - Add a new column named TotalExperience

# %%
df['TotalExperience'] = df['Experience'] + df['AdditionalExperience']

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# ##### - Modify the 'Salary' of employees with 'Education' as 'WO' to 10% more

# %%
df.loc[df['Education'] == 'WO', 'Salary'] *= 1.10

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# #### - Delete rows where 'Role' is 'Microsoft Consultant'

# %%
df = df[df['Role'] != 'Microsoft Consultant']

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# #### - Create a new column named 'SalaryCategory' with values 'Low', 'Medium', and 'High' based on salary ranges
#
# For this question, you will need to do a self-study on the Cut function from the Pandas library. Discuss it in your group and try to help each other understand its functionality well.
#
# Use these bins and labels for the categories.
# - salary_bins = [0, 3000, 5000, 8000]
# - salary_labels = ['Low', 'Medium', 'High']

# %%
# salary_bins = [0, 3000, 5000, 8000]
# salary_labels = ['Low', 'Medium', 'High']
# df['SalaryCategory'] = pd.cut(df['Salary'], bins=salary_bins, labels=salary_labels)

salary_bins = [0, 3000, 5000, 8000]
salary_labels = ['Low', 'Medium', 'High']
df.loc[:, 'SalaryCategory'] = pd.cut(df['Salary'], bins=salary_bins, labels=salary_labels)

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# #### - Add a new column named 'Bonus' and use NumPy randint to fill it with random integer values
#
# For this question, you will need to do a self-study of the randint function from the NumPy library. Discuss it in your group and try to help each other to understand its functionality well.
#
# - Generates integers between 100 and 300.

# %% [markdown]
# #### NOTE: From now on, your bonus column will have different values than what you see here, because randint generates a new random number each time we run it.

# %%
# df['Bonus'] = np.random.randint(100, 300, len(df))
df.loc[:,'Bonus'] = np.random.randint(100, 300, len(df))

df
# Out:
#     Year  Age                      Role       City Education  Experience  \
# 0   2018   42       Applicatiebeheerder     Almelo      HAVO          10
# 1   2018   38             Product owner  Rotterdam        WO          17
# 2   2018   29         Software Engineer  Eindhoven        WO           3
# 3   2019   32            Lead Developer   Randstad       HBO           8
# 4   2019   29         Software Engineer    Utrecht       HBO           6
# 5   2019   28         Software Engineer   Den Haag       HBO           5
# 6   2019   26          Support Engineer     Zwolle       MBO           2
# 7   2020   39                IT Manager  Eindhoven        WO          13
# 8   2020   33  Test Automation Engineer   Den Haag        WO           3
# 9   2020   31         Software Engineer    Tilburg       HBO           4
# 10  2020   30         Software Engineer    Utrecht        WO           5
# 11  2021   39            Lead Developer   Randstad       MBO          15
# ...

# %% [markdown]
# ### 4. Conditional Selection

# %% [markdown]
# #### - Select and display rows where 'Age' is less than 30 and 'TotalExperience' is greater than 5

# %%
selected_rows_1 = df[(df['Age'] < 30) & (df['TotalExperience'] > 5)]

selected_rows_1
# Out:
#    Year  Age               Role       City Education  Experience  Salary  \
# 2  2018   29  Software Engineer  Eindhoven        WO           3  4840.0
# 4  2019   29  Software Engineer    Utrecht       HBO           6  6400.0
# 5  2019   28  Software Engineer   Den Haag       HBO           5  5500.0
#
#    AdditionalExperience  TotalExperience SalaryCategory  Bonus
# 2                     3                6         Medium    119
# 4                     3                9           High    198
# 5                     3                8           High    286

# %% [markdown]
# #### - Select and display rows where 'City' is either 'Eindhoven' or 'Utrecht' and 'Salary' is less than 6000

# %%
selected_rows_2 = df[(df['City'].isin(['Eindhoven', 'Utrecht'])) & (df['Salary'] < 6000)]

selected_rows_2
# Out:
#     Year  Age               Role       City Education  Experience  Salary  \
# 2   2018   29  Software Engineer  Eindhoven        WO           3  4840.0
# 10  2020   30  Software Engineer    Utrecht        WO           5  5610.0
#
#     AdditionalExperience  TotalExperience SalaryCategory  Bonus
# 2                      3                6         Medium    119
# 10                     1                6           High    189

# %% [markdown]
# #### - Select and display rows where 'Education' is 'HBO' and 'Experience' is greater than 5, or 'Role' is 'Lead Developer'

# %%
selected_rows_3 = df[((df['Education'] == 'HBO') & (df['Experience'] > 5)) | (df['Role'] == 'Lead Developer')]

selected_rows_3
# Out:
#     Year  Age               Role       City Education  Experience  Salary  \
# 3   2019   32     Lead Developer   Randstad       HBO           8  3619.0
# 4   2019   29  Software Engineer    Utrecht       HBO           6  6400.0
# 11  2021   39     Lead Developer   Randstad       MBO          15  7700.0
# 12  2021   31     Lead Developer  Groningen        WO           5  5610.0
#
#     AdditionalExperience  TotalExperience SalaryCategory  Bonus
# 3                      4               12         Medium    231
# 4                      3                9           High    198
# 11                     6               21           High    260
# 12                     4                9           High    118

# %% [markdown]
# ### 5. Submission

# %%
# Save your Dataframe with the new columns added
df.to_csv('assignment_solution.csv', index=False)
